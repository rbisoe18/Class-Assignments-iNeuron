# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## control flow and conditional statements

# %% [markdown]
# Q1. Find the largest number from the given list, use for loop.
#
# ```
# numbers = [12, 75, 150, 180, 145, 525, 50]
# ```

# %% [markdown]
# Ans:

# %%
numbers = [12, 75, 150, 180, 145, 525, 50]

largest_num = numbers[0]

for num in numbers:
  if num > largest_num:
      largest_num = num
print(f"The greatest number is: {largest_num}")
# Out:
# The greatest number is: 525

# %% [markdown]
# Q2. Print all the even number between (1, 12).

# %% [markdown]
# Ans:

# %%
for i in range(1,13):
  if i%2 != 0:
    continue
  print(f"The Even numbers are: {i}")
# Out:
# The Even numbers are: 2
# The Even numbers are: 4
# The Even numbers are: 6
# The Even numbers are: 8
# The Even numbers are: 10
# The Even numbers are: 12

# %%
for i in range(1,12):
  if i%2 == 0:
    continue
  i = i+1
  print(f"The Even numbers are: {i}")
# Out:
# The Even numbers are: 2
# The Even numbers are: 4
# The Even numbers are: 6
# The Even numbers are: 8
# The Even numbers are: 10
# The Even numbers are: 12

# %% [markdown]
# Q3. Calculate the sum of all numbers from 1 to a given number
#
#     Expected Output:
#
#     Enter number 10
#
#     Sum is:  55

# %% [markdown]
# Ans:

# %%
n = int(input("Enter number: "))
sum = 0
# loop from 1 to n
for num in range(1, n + 1):
    sum = sum + num
print(f"Sum is: {sum}")
# Out:
# Enter number: 10
# Sum is: 55

# %%
n = int(input("Enter number: "))
sum = 0
# loop from 1 to n
for num in range(1, n + 1):
    print(f"Current sum is: {sum}={sum}+{num}")
    sum = sum + num
    print("------")
print(f"Sum is: {sum}")
# Out:
# Enter number: 10
# Current sum is: 0=0+1
# ------
# Current sum is: 1=1+2
# ------
# Current sum is: 3=3+3
# ------
# Current sum is: 6=6+4
# ------
# Current sum is: 10=10+5
# ------
# Current sum is: 15=15+6
# ------
# Current sum is: 21=21+7
# ------
# Current sum is: 28=28+8
# ------
# Current sum is: 36=36+9
# ------
# Current sum is: 45=45+10
# ------
# Sum is: 55

# %% [markdown]
# Q4. Write a program to display only those numbers from a list that satisfy the following conditions
#
# - The number must be divisible by five
#
# - If the number is greater than 150, then skip it and move to the next number
#
# - If the number is greater than 500, then stop the loop

# %% [markdown]
# Ans:

# %%
a = [12, 75, 150, 180, 145, 525, 50]
b = []
for i in a:
    if i > 150:
        if i > 500:
            break
        continue
    if i % 5 == 0:
        b.append(i)
        
print(b)
# Out:
# [75, 150, 145]

# %%
a = [12, 75, 150, 180, 145, 525, 50]
for i in a:

    if i % 5 ==0:
        if i > 500:
            break
        if i>150:
            continue
        print(i)
# Out:
# 75
# 150
# 145

# %% [markdown]
# Q5. Print the given list in reverse order.
#
# ```
# list1 = [10, 20, 30, 40, 50]
# ```

# %% [markdown]
# Ans:

# %%
list1 = [10, 20, 30, 40, 50]

list1.reverse()

print(list1)
# Out:
# [50, 40, 30, 20, 10]
